# %%
import scipy.io
import io
 
from data_loader import DataLoader

import numpy as np
from utils import *
from matplotlib import pyplot as plt
import numpy.random as rng
import pandas as pd
from scipy.stats import mannwhitneyu

import os
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# %run functions_to_use.ipynb
# %run results_plots.ipynb

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
rat11_safe[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rat11_safe[4]
#
# NameError: name 'rat11_safe' is not defined

# %%
import pickle

with open("results_rat_10_safe.pkl", "rb") as pkl_file:
    rat10_safe = pickle.load(pkl_file)

with open("results_rat_11_safe.pkl", "rb") as pkl_file:
    rat11_safe = pickle.load(pkl_file)

# %% [markdown]
# # Normal method

# %%
safe_0_puff_values = np.nan_to_num(rat11_safe[4]['puff_results']['values'])
safe_0_puff_time = rat11_safe[4]['puff_results']['time_points']

safe_0_safe_values = np.nan_to_num(rat11_safe[4]['safe_results']['values'])
safe_0_safe_time = rat11_safe[4]['safe_results']['time_points']

safe_0_pre_values = np.nan_to_num(rat11_safe[4]['pre_results']['values'])
safe_0_pre_time = rat11_safe[4]['pre_results']['time_points']

safe_0_post_values = np.nan_to_num(rat11_safe[4]['post_results']['values'])
safe_0_post_time = rat11_safe[4]['post_results']['time_points']

safe_1_puff_values = np.nan_to_num(rat11_safe[10]['puff_results']['values'])
safe_1_puff_time = rat11_safe[10]['puff_results']['time_points']

safe_1_safe_values = np.nan_to_num(rat11_safe[10]['safe_results']['values'])
safe_1_safe_time = np.nan_to_num(rat11_safe[10]['safe_results']['time_points'])

safe_1_pre_values = np.nan_to_num(rat11_safe[10]['pre_results']['values'])
safe_1_pre_time = np.nan_to_num(rat11_safe[10]['pre_results']['time_points'])

safe_1_post_values = np.nan_to_num(rat11_safe[10]['post_results']['values'])
safe_1_post_time = rat11_safe[10]['post_results']['time_points']

safe_2_puff_values = np.nan_to_num(rat11_safe[8]['puff_results']['values'])
safe_2_puff_time = rat11_safe[8]['puff_results']['time_points']

safe_2_safe_values = np.nan_to_num(rat11_safe[8]['safe_results']['values'])
safe_2_safe_time = rat11_safe[8]['safe_results']['time_points']

safe_2_pre_values = np.nan_to_num(rat11_safe[8]['pre_results']['values'])
safe_2_pre_time = rat11_safe[8]['pre_results']['time_points']

safe_2_post_values = np.nan_to_num(rat11_safe[8]['post_results']['values'])
safe_2_post_time = rat11_safe[8]['post_results']['time_points']

safe_3_puff_values = np.nan_to_num(rat10_safe[1]['puff_results']['values'])
safe_3_puff_time = rat10_safe[1]['puff_results']['time_points']

safe_3_safe_values = np.nan_to_num(rat10_safe[1]['safe_results']['values'])
safe_3_safe_time = rat10_safe[1]['safe_results']['time_points']

safe_3_pre_values = np.nan_to_num(rat10_safe[1]['pre_results']['values'])
safe_3_pre_time = rat10_safe[1]['pre_results']['time_points']

safe_3_post_values = np.nan_to_num(rat10_safe[1]['post_results']['values'])
safe_3_post_time = rat10_safe[1]['post_results']['time_points']

safe_4_puff_values = np.nan_to_num(rat10_safe[7]['puff_results']['values'])
safe_4_puff_time = rat10_safe[7]['puff_results']['time_points']

safe_4_safe_values = np.nan_to_num(rat10_safe[7]['safe_results']['values'])
safe_4_safe_time = np.nan_to_num(rat10_safe[7]['safe_results']['time_points'])

safe_4_pre_values = np.nan_to_num(rat10_safe[7]['pre_results']['values'])
safe_4_pre_time = np.nan_to_num(rat10_safe[7]['pre_results']['time_points'])

safe_4_post_values = np.nan_to_num(rat10_safe[7]['post_results']['values'])
safe_4_post_time = rat10_safe[7]['post_results']['time_points']

safe_5_puff_values = np.nan_to_num(rat10_safe[8]['puff_results']['values'])
safe_5_puff_time = rat10_safe[8]['puff_results']['time_points']

safe_5_safe_values = np.nan_to_num(rat10_safe[8]['safe_results']['values'])
safe_5_safe_time = rat10_safe[8]['safe_results']['time_points']

safe_5_pre_values = np.nan_to_num(rat10_safe[8]['pre_results']['values'])
safe_5_pre_time = rat10_safe[8]['pre_results']['time_points']

safe_5_post_values = np.nan_to_num(rat10_safe[8]['post_results']['values'])
safe_5_post_time = rat10_safe[8]['post_results']['time_points']

# %%
data_safe = [
    [safe_0_safe_values, safe_0_puff_values], 
    [safe_0_pre_values, safe_0_post_values], 
    [safe_1_safe_values, safe_1_puff_values],
    [safe_1_pre_values, safe_1_post_values],
    [safe_2_safe_values, safe_2_puff_values], 
    [safe_2_pre_values, safe_2_post_values], 
    [safe_3_safe_values, safe_3_puff_values],
    [safe_3_pre_values, safe_3_post_values],
    [safe_4_safe_values, safe_4_puff_values], 
    [safe_4_pre_values, safe_4_post_values], 
    [safe_5_safe_values, safe_5_puff_values], 
    [safe_5_pre_values, safe_5_post_values]]

data_safe_results = [
    [safe_1_safe_values, safe_1_puff_values],
    [safe_1_pre_values, safe_1_post_values],
    [safe_3_safe_values, safe_3_puff_values],
    [safe_3_pre_values, safe_3_post_values]]

print(len(safe_3_puff_values), len(safe_3_safe_values))

sample_1_safe = rng.choice(safe_1_puff_values, len(safe_1_safe_values), replace=False)
sample_3_safe = rng.choice(safe_3_safe_values, len(safe_3_puff_values), replace=False)

# sample_0_p = rng.choice(puff_0_pre_values, len(puff_0_post_values), replace=False)
# sample_4_p = rng.choice(puff_4_post_values, len(puff_4_pre_values), replace=False)
# sample_5_p = rng.choice(puff_5_post_values, len(puff_5_pre_values), replace=False)

data_safe_sample = [
    [safe_1_safe_values, sample_1_safe],
    [safe_1_pre_values, safe_1_post_values],
    [sample_3_safe, safe_3_puff_values],
    [safe_3_pre_values, safe_3_post_values]]
# Out:
# 36 240

# %%
n_sessions = int(len(data_safe) / 2)

# significance test
for i, (val_1, val_2) in enumerate(data_safe_sample):
    stat, p_value = mannwhitneyu(val_1, val_2, alternative='two-sided')
    if(i % 2 == 0):
        print(f"Mann Whitney U between Puff/Safe is: {stat}, with P-value: {p_value}")
    else:
        print(f"Mann Whitney U between Pre/Post is: {stat}, with P-value: {p_value}, \n")

# %%
x_positions = [0, 1, 2, 3]
plt.figure(figsize=(5,4))
values_1, values_2 = safe_1_safe_values, sample_1_safe
for i in range(len(values_1)):
    plt.scatter(x_positions[0], values_1[i], color='cornflowerblue', label='Safe' if i == 0 else "")
    plt.scatter(x_positions[1], values_2[i], color='red', label='Puff' if i == 0 else "")
plt.scatter(x_positions[0], np.mean(values_1), marker='+', s=100, color='blue', label='Safe' if i == 0 else "")
plt.scatter(x_positions[1], np.mean(values_2), marker='+', s=100, color='orange', label='Safe' if i == 0 else "")

values_1, values_2 =  sample_3_safe, safe_3_puff_values
for i in range(len(values_1)):
    plt.scatter(x_positions[2], values_1[i], color='cornflowerblue', label='Safe' if i == 0 else "")
    plt.scatter(x_positions[3], values_2[i], color='red', label='Puff' if i == 0 else "")
plt.scatter(x_positions[2], np.mean(values_1), marker='+', s=100, color='blue', label='Safe' if i == 0 else "")
plt.scatter(x_positions[3], np.mean(values_2), marker='+', s=100, color='orange', label='Safe' if i == 0 else "")

plt.xticks(x_positions, [])
# plt.yticks([])# Set the x-tick labels to 'First Half' and 'Second Half'
# plt.ylabel('Projection value')
# plt.title('Projection values for Safe and Puff runs')
# plt.legend()
# plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.ylim(-0.05, 0.65)
# plt.savefig('diff_safe.svg')
plt.show()

# %%
n_sessions = int(len(data_safe_sample) / 2)

# significance test
for i, (val_1, val_2) in enumerate(data_safe_sample):
    stat, p_value = mannwhitneyu(val_1, val_2, alternative='two-sided')
    if(i % 2 == 0):
        print(f"Mann Whitney U between Puff/Safe is: {stat}, with P-value: {p_value}")
    else:
        print(f"Mann Whitney U between Pre/Post is: {stat}, with P-value: {p_value}, \n")

# scatter of all values
scatter_projection(data_safe_sample)

# # comparison of values on left and right axes

# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_safe_sample):
#     row, col = divmod(i, 2)  
#     safe_puff = (i % 2 == 0) 
#     plot_comparison_subplots(values_1, values_2, safe_puff, 1, axes[row, col])

# plt.tight_layout()
# plt.show()

# # difference plot
# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_safe_sample):
#     row, col = divmod(i, 2)  
#     if(i % 2 == 0):
#         scatter_differences_subplot(values_2, values_1, "Puff", "Safe", axes[row, col])
#     else: 
#         scatter_differences_subplot(values_2, values_1, "Post", "Pre", axes[row, col])

# plt.tight_layout()
# plt.show()

# %%
mean_safe = [np.mean(safe_1_safe_values), np.mean(safe_3_safe_values)]
mean_puff = [np.mean(safe_1_puff_values), np.mean(safe_3_puff_values)]


values_1, values_2 = mean_safe, mean_puff
for i in range(len(values_1)):
    plt.scatter(x_positions[2], values_1[i], color='blue', label='Safe' if i == 0 else "")
    plt.scatter(x_positions[3], values_2[i], color='orange', label='Puff' if i == 0 else "")
# plt.scatter(x_positions[2], np.mean(values_1), marker='+', s=100, color='blue', label='Safe' if i == 0 else "")
# plt.scatter(x_positions[3], np.mean(values_2), marker='+', s=100, color='orange', label='Safe' if i == 0 else "")
plt.xticks([])
# plt.grid(True, axis='x', alpha=0.3 )
# plt.savefig('mean_safe_.svg')

mannwhitneyu(values_1, values_2, alternative='two-sided')

# %% [markdown]
# # With bigger window

# %%
with open("results_rat_10_safe_big.pkl", "rb") as pkl_file:
    rat10_safe_big = pickle.load(pkl_file)

with open("results_rat_11_safe_big.pkl", "rb") as pkl_file:
    rat11_safe_big = pickle.load(pkl_file)

# %%
rat10_safe_big[2]

# %%
big_0_puff_values = np.nan_to_num(rat11_safe_big[0]['puff_results']['values'])
big_0_puff_time = rat11_safe_big[0]['puff_results']['time_points']

big_0_safe_values = np.nan_to_num(rat11_safe_big[0]['safe_results']['values'])
big_0_safe_time = rat11_safe_big[0]['safe_results']['time_points']

big_0_pre_values = np.nan_to_num(rat11_safe_big[0]['pre_results']['values'])
big_0_pre_time = rat11_safe_big[0]['pre_results']['time_points']

big_0_post_values = np.nan_to_num(rat11_safe_big[0]['post_results']['values'])
big_0_post_time = rat11_safe_big[0]['post_results']['time_points']

big_1_puff_values = np.nan_to_num(rat11_safe_big[1]['puff_results']['values'])
big_1_puff_time = rat11_safe_big[1]['puff_results']['time_points']

big_1_safe_values = np.nan_to_num(rat11_safe_big[1]['safe_results']['values'])
big_1_safe_time = np.nan_to_num(rat11_safe_big[1]['safe_results']['time_points'])

big_1_pre_values = np.nan_to_num(rat11_safe_big[1]['pre_results']['values'])
big_1_pre_time = np.nan_to_num(rat11_safe_big[1]['pre_results']['time_points'])

big_1_post_values = np.nan_to_num(rat11_safe_big[1]['post_results']['values'])
big_1_post_time = rat11_safe_big[1]['post_results']['time_points']

big_2_puff_values = np.nan_to_num(rat11_safe_big[2]['puff_results']['values'])
big_2_puff_time = rat11_safe_big[2]['puff_results']['time_points']

big_2_safe_values = np.nan_to_num(rat11_safe_big[2]['safe_results']['values'])
big_2_safe_time = rat11_safe_big[2]['safe_results']['time_points']

big_2_pre_values = np.nan_to_num(rat11_safe_big[2]['pre_results']['values'])
big_2_pre_time = rat11_safe_big[2]['pre_results']['time_points']

big_2_post_values = np.nan_to_num(rat11_safe_big[2]['post_results']['values'])
big_2_post_time = rat11_safe_big[2]['post_results']['time_points']

big_3_puff_values = np.nan_to_num(rat10_safe_big[0]['puff_results']['values'])
big_3_puff_time = rat10_safe_big[0]['puff_results']['time_points']

big_3_safe_values = np.nan_to_num(rat10_safe_big[0]['safe_results']['values'])
big_3_safe_time = rat10_safe_big[0]['safe_results']['time_points']

big_3_pre_values = np.nan_to_num(rat10_safe_big[0]['pre_results']['values'])
big_3_pre_time = rat10_safe_big[0]['pre_results']['time_points']

big_3_post_values = np.nan_to_num(rat10_safe_big[0]['post_results']['values'])
big_3_post_time = rat10_safe_big[0]['post_results']['time_points']

big_4_puff_values = np.nan_to_num(rat10_safe_big[1]['puff_results']['values'])
big_4_puff_time = rat10_safe_big[1]['puff_results']['time_points']

big_4_safe_values = np.nan_to_num(rat10_safe_big[1]['safe_results']['values'])
big_4_safe_time = np.nan_to_num(rat10_safe_big[1]['safe_results']['time_points'])

big_4_pre_values = np.nan_to_num(rat10_safe_big[1]['pre_results']['values'])
big_4_pre_time = np.nan_to_num(rat10_safe_big[1]['pre_results']['time_points'])

big_4_post_values = np.nan_to_num(rat10_safe_big[1]['post_results']['values'])
big_4_post_time = rat10_safe_big[1]['post_results']['time_points']

# %%
data_big = [
    [big_0_safe_values, big_0_puff_values], 
    [big_1_safe_values, big_1_puff_values],
    [big_2_safe_values, big_2_puff_values],
    [big_3_safe_values, big_3_puff_values],
    [big_4_safe_values, big_4_puff_values]
]

# %%
print(len(big_2_puff_values), len(big_2_safe_values))
print(len(big_3_puff_values), len(big_3_safe_values))


sample_2_b = rng.choice(big_2_puff_values, len(big_2_safe_values), replace=False)
sample_3_b = rng.choice(big_3_safe_values, len(big_3_puff_values), replace=False)
# sample_2_b = rng.choice(big_2_safe_values, len(big_2_puff_values), replace=False)

data_big_sample = [
    [big_2_safe_values, sample_2_b], 
    [sample_3_b, big_3_puff_values]]

# %%
# n_sessions = int(len(data_big_sample) / 2)

# significance test
for i, (val_1, val_2) in enumerate(data_big_sample):
    stat, p_value = mannwhitneyu(val_1, val_2, alternative='two-sided')
    if(i % 2 == 0):
        print(f"Mann Whitney U between Puff/Safe is: {stat}, with P-value: {p_value}")
    else:
        print(f"Mann Whitney U between Pre/Post is: {stat}, with P-value: {p_value}, \n")

# # scatter of all values
scatter_projection(data_big_sample)

# # comparison of values on left and right axes

# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_big):
#     row, col = divmod(i, 2)  
#     safe_puff = (i % 2 == 0) 
#     plot_comparison_subplots(values_1, values_2, safe_puff, 1, axes[row, col])

# plt.tight_layout()
# plt.show()

# # difference plot
# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_big):
#     row, col = divmod(i, 2)  
#     if(i % 2 == 0):
#         scatter_differences_subplot(values_2, values_1, "Puff", "Safe", axes[row, col])
#     else: 
#         scatter_differences_subplot(values_2, values_1, "Post", "Pre", axes[row, col])

# plt.tight_layout()
# plt.show()
# plt.figure()
# data_safe_big = flatten([sample_0_b, sample_1_b, sample_2_b])
# data_puff_big = flatten([big_0_puff_values, big_1_puff_values, big_2_puff_values])
# plt.scatter(np.arange(len(data_safe_big)), data_safe_big, color='b')
# plt.scatter(np.arange(len(data_puff_big)), data_puff_big, color='r')
# plt.grid(True, alpha=0.3)

plt.plot(big_2_safe_values, color='cornflowerblue', alpha=0.8)
plt.plot(sample_2_b, color='red', alpha=0.8)
plt.show()

plt.plot(sample_3_b, color='cornflowerblue', alpha=0.8)
plt.plot(big_3_puff_values,  color='red', alpha=0.8)
plt.show()

# %%
x_positions = [0, 1, 2, 3]
plt.figure(figsize=(5,4))
values_1, values_2 = big_2_safe_values, sample_2_b


for i in range(len(values_1)):
    plt.scatter(x_positions[0], values_1[i], color='cornflowerblue', label='Safe' if i == 0 else "")
    plt.scatter(x_positions[1], values_2[i], color='red', label='Puff' if i == 0 else "")
plt.scatter(x_positions[0], np.mean(values_1), marker='+', s=100, color='blue', label='Safe' if i == 0 else "")
plt.scatter(x_positions[1], np.mean(values_2), marker='+', s=100, color='orange', label='Safe' if i == 0 else "")

values_1, values_2 =  sample_3_b, big_3_puff_values
for i in range(len(values_1)):
    plt.scatter(x_positions[2], values_1[i], color='cornflowerblue', label='Safe' if i == 0 else "")
    plt.scatter(x_positions[3], values_2[i], color='red', label='Puff' if i == 0 else "")
plt.scatter(x_positions[2], np.mean(values_1), marker='+', s=100, color='blue', label='Safe' if i == 0 else "")
plt.scatter(x_positions[3], np.mean(values_2), marker='+', s=100, color='orange', label='Safe' if i == 0 else "")

plt.xticks(x_positions, [])
# plt.yticks([])# Set the x-tick labels to 'First Half' and 'Second Half'
# plt.ylabel('Projection value')
# plt.title('Projection values for Safe and Puff runs')
# plt.legend()
# plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.ylim(-0.05, 0.65)
# plt.savefig('diff_safe.svg')
plt.show()





mean_safe_big = []
mean_puff_big = []
for (i, j) in data_big_sample:
    mean_safe_big.append(np.mean(i))
    mean_puff_big.append(np.mean(j))

plot_comparison(mean_safe_big, mean_puff_big, True, 1)

mannwhitneyu(mean_safe_big, mean_puff_big, alternative='two-sided')

# %% [markdown]
# # With MI values

# %%
with open("results_rat_11_safe_seq.pkl", "rb") as pkl_file:
    rat11_seq = pickle.load(pkl_file)

with open("results_rat_10_safe_seq.pkl", "rb") as pkl_file:
    rat10_seq = pickle.load(pkl_file)

seq_0_puff_values = np.nan_to_num(rat11_seq[0]['puff_results']['values'])
seq_0_puff_time = rat11_seq[0]['puff_results']['time_points']

seq_0_safe_values = np.nan_to_num(rat11_seq[0]['safe_results']['values'])
seq_0_safe_time = rat11_seq[0]['safe_results']['time_points']

seq_0_pre_values = np.nan_to_num(rat11_seq[0]['pre_results']['values'])
seq_0_pre_time = rat11_seq[0]['pre_results']['time_points']

seq_0_post_values = np.nan_to_num(rat11_seq[0]['post_results']['values'])
seq_0_post_time = rat11_seq[0]['post_results']['time_points']

seq_1_puff_values = np.nan_to_num(rat11_seq[1]['puff_results']['values'])
seq_1_puff_time = rat11_seq[1]['puff_results']['time_points']

seq_1_safe_values = np.nan_to_num(rat11_seq[1]['safe_results']['values'])
seq_1_safe_time = np.nan_to_num(rat11_seq[1]['safe_results']['time_points'])

seq_1_pre_values = np.nan_to_num(rat11_seq[1]['pre_results']['values'])
seq_1_pre_time = np.nan_to_num(rat11_seq[1]['pre_results']['time_points'])

seq_1_post_values = np.nan_to_num(rat11_seq[1]['post_results']['values'])
seq_1_post_time = rat11_seq[1]['post_results']['time_points']

seq_2_puff_values = np.nan_to_num(rat11_seq[2]['puff_results']['values'])
seq_2_puff_time = rat11_seq[2]['puff_results']['time_points']

seq_2_safe_values = np.nan_to_num(rat11_seq[2]['safe_results']['values'])
seq_2_safe_time = rat11_seq[2]['safe_results']['time_points']

seq_2_pre_values = np.nan_to_num(rat11_seq[2]['pre_results']['values'])
seq_2_pre_time = rat11_seq[2]['pre_results']['time_points']

seq_2_post_values = np.nan_to_num(rat11_seq[2]['post_results']['values'])
seq_2_post_time = rat11_seq[2]['post_results']['time_points']

seq_3_puff_values = np.nan_to_num(rat10_seq[0]['puff_results']['values'])
seq_3_puff_time = rat10_seq[0]['puff_results']['time_points']

seq_3_safe_values = np.nan_to_num(rat10_seq[0]['safe_results']['values'])
seq_3_safe_time = np.nan_to_num(rat10_seq[0]['safe_results']['time_points'])

seq_3_pre_values = np.nan_to_num(rat10_seq[0]['pre_results']['values'])
seq_3_pre_time = np.nan_to_num(rat10_seq[0]['pre_results']['time_points'])

seq_3_post_values = np.nan_to_num(rat10_seq[0]['post_results']['values'])
seq_3_post_time = rat10_seq[0]['post_results']['time_points']

seq_4_puff_values = np.nan_to_num(rat10_seq[1]['puff_results']['values'])
seq_4_puff_time = rat10_seq[1]['puff_results']['time_points']

seq_4_safe_values = np.nan_to_num(rat10_seq[1]['safe_results']['values'])
seq_4_safe_time = rat10_seq[1]['safe_results']['time_points']

seq_4_pre_values = np.nan_to_num(rat10_seq[1]['pre_results']['values'])
seq_4_pre_time = rat10_seq[1]['pre_results']['time_points']

seq_4_post_values = np.nan_to_num(rat10_seq[1]['post_results']['values'])
seq_4_post_time = rat10_seq[1]['post_results']['time_points']

# %%
data_seq = [
    [seq_0_safe_values, seq_0_puff_values], 
    [seq_0_pre_values, seq_0_post_values], 
    [seq_1_safe_values, seq_1_puff_values],
    [seq_1_pre_values, seq_1_post_values],
    [seq_2_safe_values, seq_2_puff_values], 
    [seq_2_pre_values, seq_2_post_values], 
    [seq_3_safe_values, seq_3_puff_values],
    [seq_3_pre_values, seq_3_post_values],
]

# data_seq_results = [
#     [seq_0_safe_values, seq_0_puff_values], 
#     [seq_0_pre_values, seq_0_post_values],
#     [seq_3_safe_values, seq_3_puff_values],
#     [seq_3_pre_values, seq_3_post_values],
#     [seq_4_safe_values, seq_4_puff_values], 
#     [seq_4_pre_values, seq_4_post_values], 
#     [seq_5_safe_values, seq_5_puff_values], 
#     [seq_5_pre_values, seq_5_post_values],
#     [seq_6_safe_values, seq_6_puff_values], 
#     [seq_6_pre_values, seq_6_post_values]]

# sample_seq_0 = rng.choice(seq_0_safe_values, len(seq_0_puff_values), replace=False)
# sample_seq_3 = rng.choice(seq_3_safe_values, len(seq_3_puff_values), replace=False)
# sample_seq_4 = rng.choice(seq_4_safe_values, len(seq_4_puff_values), replace=False)
# sample_seq_5 = rng.choice(seq_5_safe_values, len(seq_5_puff_values), replace=False)
# sample_seq_6 = rng.choice(seq_6_safe_values, len(seq_6_puff_values), replace=False)

# data_seq_results = [
#     [sample_seq_0, seq_0_puff_values], 
#     [seq_0_pre_values, seq_0_post_values],
#     [sample_seq_3, seq_3_puff_values],
#     [seq_3_pre_values, seq_3_post_values],
#     [sample_seq_4, seq_4_puff_values], 
#     [seq_4_pre_values, seq_4_post_values], 
#     [sample_seq_5, seq_5_puff_values], 
#     [seq_5_pre_values, seq_5_post_values],
#     [sample_seq_6, seq_6_puff_values], 
#     [seq_6_pre_values, seq_6_post_values]]

# %%
n_sessions = int(len(data_seq) / 2)

# significance test
for i, (val_1, val_2) in enumerate(data_seq):
    stat, p_value = mannwhitneyu(val_1, val_2, alternative='two-sided')
    if(i % 2 == 0):
        print(f"Mann Whitney U between Puff/Safe is: {stat}, with P-value: {p_value}")
    else:
        print(f"Mann Whitney U between Pre/Post is: {stat}, with P-value: {p_value}, \n")

# scatter of all values
scatter_projection(data_seq)

# data_safe_ = flatten([sample_seq_0, sample_seq_3, sample_seq_4, sample_seq_5, sample_seq_6]) # sample_4, sample_5]) 
# data_puff_ = flatten([seq_0_puff_values, seq_3_puff_values, seq_4_puff_values, seq_5_puff_values, seq_6_puff_values]) #, puff_4_puff_values, puff_5_puff_values])
# plt.scatter(np.arange(len(data_safe_)), data_safe_, color='dodgerblue')
# plt.scatter(np.arange(len(data_puff_)), data_puff_, color='r')
# plt.grid(True, alpha=0.3)
# plt.ylim(-0.02, 0.38)
# plt.savefig('more_puff_than_safe.svg')

# # comparison of values on left and right axes

# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_seq):
#     row, col = divmod(i, 2)  
#     safe_puff = (i % 2 == 0) 
#     plot_comparison_subplots(values_1, values_2, safe_puff, 1, axes[row, col])

# plt.tight_layout()
# plt.show()

# # difference plot
# fig, axes = plt.subplots(n_sessions, 2, figsize=(12, n_sessions*4))
# for i, (values_1, values_2) in enumerate(data_seq):
#     row, col = divmod(i, 2)  
#     if(i % 2 == 0):
#         scatter_differences_subplot(values_2, values_1, "Puff", "Safe", axes[row, col])
#     else: 
#         scatter_differences_subplot(values_2, values_1, "Post", "Pre", axes[row, col])

# plt.tight_layout()
# plt.show()

# %%
# GET PUFF VARIABLES
# RAT 11

seq_0_puff_values = np.nan_to_num(rat11_seq[0]['puff_results']['values'])
seq_0_puff_time = rat11_seq[0]['puff_results']['time_points']

seq_0_safe_values = np.nan_to_num(rat11_seq[0]['safe_results']['values'])
seq_0_safe_time = rat11_seq[0]['safe_results']['time_points']

seq_0_pre_values = np.nan_to_num(rat11_seq[0]['pre_results']['values'])
seq_0_pre_time = rat11_seq[0]['pre_results']['time_points']

seq_0_post_values = np.nan_to_num(rat11_seq[0]['post_results']['values'])
seq_0_post_time = rat11_seq[0]['post_results']['time_points']

seq_1_puff_values = np.nan_to_num(rat11_seq[1]['puff_results']['values'])
seq_1_puff_time = rat11_seq[1]['puff_results']['time_points']

seq_1_safe_values = np.nan_to_num(rat11_seq[1]['safe_results']['values'])
seq_1_safe_time = np.nan_to_num(rat11_seq[1]['safe_results']['time_points'])

seq_1_pre_values = np.nan_to_num(rat11_seq[1]['pre_results']['values'])
seq_1_pre_time = np.nan_to_num(rat11_seq[1]['pre_results']['time_points'])

seq_1_post_values = np.nan_to_num(rat11_seq[1]['post_results']['values'])
seq_1_post_time = rat11_seq[1]['post_results']['time_points']

seq_2_puff_values = np.nan_to_num(rat11_seq[4]['puff_results']['values'])
seq_2_puff_time = rat11_seq[4]['puff_results']['time_points']

seq_2_safe_values = np.nan_to_num(rat11_seq[4]['safe_results']['values'])
seq_2_safe_time = rat11_seq[4]['safe_results']['time_points']

seq_2_pre_values = np.nan_to_num(rat11_seq[4]['pre_results']['values'])
seq_2_pre_time = rat11_seq[4]['pre_results']['time_points']

seq_2_post_values = np.nan_to_num(rat11_seq[4]['post_results']['values'])
seq_2_post_time = rat11_seq[4]['post_results']['time_points']

seq_3_puff_values = np.nan_to_num(rat11_seq[5]['puff_results']['values'])
seq_3_puff_time = rat11_seq[5]['puff_results']['time_points']

seq_3_safe_values = np.nan_to_num(rat11_seq[5]['safe_results']['values'])
seq_3_safe_time = np.nan_to_num(rat11_seq[5]['safe_results']['time_points'])

seq_3_pre_values = np.nan_to_num(rat11_seq[5]['pre_results']['values'])
seq_3_pre_time = np.nan_to_num(rat11_seq[5]['pre_results']['time_points'])

seq_3_post_values = np.nan_to_num(rat11_seq[5]['post_results']['values'])
seq_3_post_time = rat11_seq[5]['post_results']['time_points']

seq_4_puff_values = np.nan_to_num(rat11_seq[6]['puff_results']['values'])
seq_4_puff_time = rat11_seq[6]['puff_results']['time_points']

seq_4_safe_values = np.nan_to_num(rat11_seq[6]['safe_results']['values'])
seq_4_safe_time = rat11_seq[6]['safe_results']['time_points']

seq_4_pre_values = np.nan_to_num(rat11_seq[6]['pre_results']['values'])
seq_4_pre_time = rat11_seq[6]['pre_results']['time_points']

seq_4_post_values = np.nan_to_num(rat11_seq[6]['post_results']['values'])
seq_4_post_time = rat11_seq[6]['post_results']['time_points']


# RAT 10

seq_5_puff_values = np.nan_to_num(rat10_seq[5]['puff_results']['values'])
seq_5_puff_time = rat10_seq[5]['puff_results']['time_points']

seq_5_safe_values = np.nan_to_num(rat10_seq[5]['safe_results']['values'])
seq_5_safe_time = rat10_seq[5]['safe_results']['time_points']

seq_5_pre_values = np.nan_to_num(rat10_seq[5]['pre_results']['values'])
seq_5_pre_time = rat10_seq[5]['pre_results']['time_points']

seq_5_post_values = np.nan_to_num(rat10_seq[5]['post_results']['values'])
seq_5_post_time = rat10_seq[5]['post_results']['time_points']

# RAT 08

seq_6_puff_values = np.nan_to_num(rat8_seq[0]['puff_results']['values'])
seq_6_puff_time = rat8_seq[0]['puff_results']['time_points']

seq_6_safe_values = np.nan_to_num(rat8_seq[0]['safe_results']['values'])
seq_6_safe_time = rat8_seq[0]['safe_results']['time_points']

seq_6_pre_values = np.nan_to_num(rat8_seq[0]['pre_results']['values'])
seq_6_pre_time = rat8_seq[0]['pre_results']['time_points']

seq_6_post_values = np.nan_to_num(rat8_seq[0]['post_results']['values'])
seq_6_post_time = rat8_seq[0]['post_results']['time_points']

# %% [markdown]
# # Reactivation SWRS

# %%
data_safe_ripples = [
    [safe_1_pre_values, safe_1_post_values], 
    [safe_3_pre_values, safe_3_post_values]]

print(len(safe_1_pre_values), len(safe_1_post_values), len(safe_3_pre_values), len(safe_3_post_values))

sample_1 = rng.choice(safe_1_post_values, len(safe_1_pre_values), replace=False)
sample_3 = rng.choice(safe_3_pre_values, len(safe_3_post_values), replace=False)

ripples_sample = [
    [safe_1_pre_values, sample_1], 
    [sample_3, safe_3_post_values]]
# significance test
for i, (val_1, val_2) in enumerate(data_safe_ripples):
    stat, p_value = mannwhitneyu(val_1, val_2, alternative='two-sided')
    if(i % 2 == 0):
        print(f"Mann Whitney U between Puff/Safe is: {stat}, with P-value: {p_value}")
    else:
        print(f"Mann Whitney U between Pre/Post is: {stat}, with P-value: {p_value}, \n")
# Out:
# 3893 4321 7073 6082
# Mann Whitney U between Puff/Safe is: 8374296.0, with P-value: 0.15754472209441772
# Mann Whitney U between Pre/Post is: 21160297.5, with P-value: 0.007179144322052464,

# %%
def plot_cdf(data, label, color):
    sorted_data = np.sort(data)
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    plt.plot(sorted_data, cdf, label=label, color=color, alpha=0.5)


pre_sleep, post_sleep = safe_1_pre_values, sample_1
plt.plot(pre_sleep, color='blue', alpha=0.5)
plt.plot(post_sleep, color='red', alpha=0.5)
plt.show()

plt.figure(figsize=(8, 6))
plot_cdf(pre_sleep, "Pre-sleep", "cornflowerblue")
plot_cdf(post_sleep, "Post-sleep (Left)", "red")
# plt.savefig('cdf_ripples_i.svg')
plt.show()

pre_sleep, post_sleep = sample_3, safe_3_post_values
plt.plot(pre_sleep, color='blue', alpha=0.5)
plt.plot(post_sleep, color='red', alpha=0.5)
plt.show()

plt.figure(figsize=(8, 6))
plot_cdf(pre_sleep, "Pre-sleep", "cornflowerblue")
plot_cdf(post_sleep, "Post-sleep (Left)", "red")
# plt.savefig('cdf_ripples_i.svg')
plt.show()

# %%
idxs_1_pr = np.nonzero(safe_1_pre_values)
vals_1_pr = safe_1_pre_values[idxs_1_pr]

idxs_1_po = np.nonzero(sample_1)
vals_1_po = sample_1[idxs_1_po]

idxs_3_pr = np.nonzero(sample_3)
vals_3_pr = sample_3[idxs_1_pr]

idxs_3_po = np.nonzero(safe_3_post_values)
vals_3_po = safe_3_post_values[idxs_1_po]

print(len(vals_1_pr), len(safe_1_pre_values))
print(len(vals_1_po), len(safe_1_post_values))
print(len(vals_3_pr), len(safe_3_pre_values))
print(len(vals_3_po), len(safe_3_post_values))

81/6082
# Out:
# 68 3893
# 83 4321
# 68 7073
# 83 6082
# 0.01331798750411049

# %%
plt.hist(vals_1_pr, bins=30,color='cornflowerblue', alpha=0.6)
plt.hist(vals_1_po, bins=30,  color='red',alpha=0.6)
# plt.savefig('hist_rip_1.svg')
plt.show()

plt.hist(vals_3_pr, bins=30,color='cornflowerblue', alpha=0.6)
plt.hist(vals_3_po, bins=30,  color='red',alpha=0.6)
# plt.savefig('hist_rip_2.svg')
plt.show()


print(np.mean(safe_1_pre_values), np.mean(safe_1_post_values))
print(np.mean(safe_3_pre_values), np.mean(safe_3_post_values))
# Out:
# 0.003712641999743519 0.005288886056239949
# 0.013625427229404933 0.014864394462912975
